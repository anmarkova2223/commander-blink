# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import *

# %%
df = pd.read_csv('trial_1.csv', sep='\t')

# %%
df.columns = list(range(len(df.columns)))

# %%
# function to bandpass filter
def lowpass(sig, fc, fs, butter_filt_order):
    B,A = butter(butter_filt_order, np.array(fc)/(fs/2), btype='low')
    return lfilter(B, A, sig, axis=0)

lowpass(y, 10, 250, 4)
# Out:
# array([1.28658008e+00, 1.07424085e+01, 4.46517144e+01, ...,
#        7.65467890e+03, 7.65401350e+03, 7.65344393e+03])

# %%
y = df[1].to_list()#[10000:20000]
x = df.index.to_list()#[10000:20000]
y2 = lowpass(y, 10, 250, 4)
plt.plot(x, y2)
plt.ylim((5000,9000))
# Out:
# (5000.0, 9000.0)

# %%
# Out:
#   Cell In[35], line 1
#     from EEG-EyeBlinks/blink import *
#             ^
# SyntaxError: invalid syntax
